# %% [markdown]
# # Mini Report
# ---
# ## Introduction
#
# Hello! My name is **Hrishikesh Rao**.
# I am in my 3rd semester,electronics and communication in **UVCE**.
#
# ---
#
# ## Interests
#
# Here are my interests:
# - Listening to **music** of all genres.
# - Playing **Football** and **Badminton**.
# - Watching **Movies**.
# - Watching **Formula1**.
# ---
#
# ## Goals
#
# Here are three things I want to achieve:
# - *Learn **Machine Learning**.*
# - *Learn about more **Core electronics**.*
# - *Maintain good academics*
#
# ---
#
# ## Embedded Image
#
# ### **Here’s a cool photo of the mercedes f1 car !**
#
#  ![](https://library.sportingnews.com/styles/twitter_card_120x120/s3/2021-08/formula1-073020-getty-ftrjpg_1dqym4pv2cnow1t2yfqqix3vly.jpg?itok=E3lg-BUA)
#
# ---

# %% [markdown]
# # Coding
# ---
#
# ## Small Code Snippet
# ```python
# #Sum of two numbers
# x=5
# y=3
# print("Sum=",x+y)

# %% [markdown]
# ---
# ## Plotting a sine wave using Matplotlib and Numpy!

# %%
import numpy as np
import matplotlib.pyplot as plt


x = np.arange(0, 6.28, 0.01)   # step =0.1,start index =0,end index =6.28.

# Sine function
y = np.sin(x)

# Plot
plt.plot(x, y,linewidth=1.5)   
plt.title("Sine Wave")
plt.xlabel("x")
plt.ylabel("sin(x)")
plt.grid(True)

plt.show()

# %% [markdown]
# ---

# %% [markdown]
# # Conclusion
#
# - Personally **Jupyter Notebook** is a great tool for coding, especially coding with explaining as it includes markdown as well which explains stuff really well from the conventional use of comments in code.
# - Also whilst learning to code, we also learn how to write **Markdown** script which is very useful for writing reports.
# - The feature to include code snippets is also amazing.

# %% [markdown]
# # **Thank You :D**
